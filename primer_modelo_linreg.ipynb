# %%
import pandas as pd
import seaborn as sb

datos = pd.read_csv("celsius-fahrenheit.csv")

# %%
datos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   celsius     7 non-null      int64
#  1   fahrenheit  7 non-null      float64
# dtypes: float64(1), int64(1)
# memory usage: 244.0 bytes

# %%
datos.head()
# Out:
#    celsius  fahrenheit
# 0      -40       -40.0
# 1      -10        14.0
# 2        0        32.0
# 3        8        46.4
# 4       15        59.0

# %%
sb.scatterplot(x="celsius", y="fahrenheit", data=datos,
               hue="fahrenheit", palette="coolwarm")
# Out:
# <Axes: xlabel='celsius', ylabel='fahrenheit'>

# %%
#Características (X), etiqueta(y)

X= datos['celsius']
y= datos['fahrenheit']

# %%
X_procesada = X.values.reshape(-1,1)
y_procesada = y.values.reshape(-1,1)

# %%
from sklearn.linear_model import LinearRegression

modelo = LinearRegression()

# %%
#Entrenamiento

print("Entrenando modelo...")
modelo.fit(X_procesada, y_procesada)
# Out:
# Entrenando modelo...
# LinearRegression()

# %%
#Predicción

celsius = 400

prediccion = modelo.predict([[celsius]])
print(f'{celsius} grados celsius son {prediccion} grados fahrenheit')
# Out:
# 400 grados celsius son [[752.]] grados fahrenheit

# %%
modelo.score(X_procesada, y_procesada)
# Out:
# 1.0
